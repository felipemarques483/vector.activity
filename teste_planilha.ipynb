# %% [markdown]
# <a href="https://colab.research.google.com/github/felipemarques483/vector.activity/blob/main/teste_planilha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
ss = gc.open_by_url('https://docs.google.com/spreadsheets/d/1voKCp0MJOelI0-qv9s_m3VF5GUvkS4lbKyArA6NbmTs/edit#gid=1902849498')

# %%
import pandas as pd

# %%
sheet = ss.get_worksheet(0)

# %%
dados = sheet.get_all_records()

df = pd.DataFrame(dados)
df.head(5)

# %%
df[['Data', 'Carro', 'Problema']]

datas, carros, problemas = [], [], []

for data, carro, problema  in zip(df['Data'], df['Carro'], df['Problema']):
  # carros.append(carro) if not carro in carros else 0
  if data == '01/11/2023' and problema != '':
    datas.append(data)
    carros.append(carro)
    problemas.append(problema)

  #print(f'{data} -> {carro} -> {problema}') if problema != '' else 0#if data == '01/11/2023' else 0
# carros

# %%
planilha = {
    'Data': datas,
    'Carro': carros,
    'Problema': problemas
}
pd.DataFrame(planilha)
# Out:
#          Data  Carro                  Problema
# 0  01/11/2023   6731       Elétrica - Letreiro
# 1  01/11/2023   6808       Carroceria - Portas
# 2  01/11/2023   6644   Elétrica - Sem arranque
# 3  01/11/2023   6111       Elétrica - Letreiro
# 4  01/11/2023   6122       Carroceria - Portas
# 5  01/11/2023   6484  Elétrica - Pane elétrica
# 6  01/11/2023   6124       Elétrica - Letreiro
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['Carro'].plot(kind='hist', bins=20, title='Carro')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('Problema').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
